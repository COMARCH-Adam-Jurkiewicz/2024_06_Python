# %%
import pandas as pd

# %%
df = pd.read_excel("RIRS_RP_KOT_W_WORKU.xlsb")
df
# Out:
#          ROK  MIESIAC  TYDZIEN  DZIEN  OMNICODE_ORDER   OMNICODE_BUNDLE  \
# 0       2023        1        1  44928  OMNI0480369971  OMNI0480369971X1
# 1       2023        1        1  44928  OMNI0480371293  OMNI0480371293X1
# 2       2023        1        1  44928  OMNI0480371360  OMNI0480371360X1
# 3       2023        1        1  44928  OMNI0480371360  OMNI0480371360X2
# 4       2023        1        1  44928  OMNI0480371360  OMNI0480371360X3
# ...      ...      ...      ...    ...             ...               ...
# 117974  2024        6       26  45467  OMNI0715661965  OMNI0715661965X2
# 117975  2024        6       26  45467  OMNI0715676783  OMNI0715676783X1
# 117976  2024        6       26  45467  OMNI0715676847  OMNI0715676847X1
# 117977  2024        6       26  45467  OMNI0715684324  OMNI0715684324X1
# 117978  2024        6       26  45467  OMNI0715703193  OMNI0715703193X1
#
#        ID_RODZ_REALIZACJI  DATA_KONCA_PROCESU  MIESIAC_DORECZENIA  \
# ...

# %%
df.describe()
# Out:
#                  ROK        MIESIAC        TYDZIEN          DZIEN  \
# count  117979.000000  117979.000000  117979.000000  117979.000000
# mean     2023.342646       5.514346      22.152680   45203.156663
# std         0.474596       3.414524      14.807596     157.015670
# min      2023.000000       1.000000       1.000000   44928.000000
# 25%      2023.000000       3.000000      10.000000   45064.000000
# 50%      2023.000000       5.000000      19.000000   45210.000000
# 75%      2024.000000       8.000000      34.000000   45337.000000
# max      2024.000000      12.000000      52.000000   45467.000000
#
#        DATA_KONCA_PROCESU  MIESIAC_DORECZENIA  TYDZIEN_DORECZENIA  \
# count       116568.000000        88536.000000        88536.000000
# mean         45204.839244            5.591996           22.633946
# std            156.067071            3.401641           14.740022
# min          44929.000000            1.000000            1.000000
# ...
