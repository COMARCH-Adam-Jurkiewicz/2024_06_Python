# %%
# Render our plots inline
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Make the graphs a bit prettier, and bigger
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 5)

# %%
data_frame = pd.read_csv("OMNI.csv", delimiter=";")

# %%
data_frame
# Out:
#    P_SALESCHANNEL ID_ZLEC_W_KANALE   P_ORDERNUMBERSAP QUEUE  \
# 0             POS   OMNI0679358527           21553381     6
# 1             POS   OMNI0693948297           21754475     6
# 2             POS   OMNI0697643876           21812049     6
# 3             POS   OMNI0697643876           21812049     6
# 4             IDG   OMNI0701650778           21874900     6
# 5             POS   OMNI0701762396           21878163     6
# 6             WWW   OMNI0702550433           21892045     6
# 7             POS   OMNI0706281594  21945761#21945763   6#6
# 8             IDG   OMNI0709886829           22003276     6
# 9             TLS   OMNI0709924606           22003117     6
# 10            TLS   OMNI0710039950           22006279     6
# 11            POS   OMNI0709479641           21997367     6
# 12            TLS   OMNI0710023289           22005554     6
# 13            TLS   OMNI0710610437           22015667     6
# 14            TLS   OMNI0710673050           22017462     6
# 15            POS   OMNI0710072711           22007313     6
# 16            POS   OMNI0710072711           22007313     6
# 17            IDG   OMNI0710586436           22015023     6
# 18            WWW   OMNI0711685576           22028917     6
# 19            TLS   OMNI0712468292           22044782     6
#
#               STATUSID         SALESOFFICE       SHIPPINGCONDITION  \
# 0            Delivered              POSOwn                  Pickup
# 1            Delivered            POSAgent                  Pickup
# 2            Delivered              POSOwn                  Pickup
# 3            Delivered              POSOwn                  Pickup
# 4            Delivered        PickUpPortal                  Pickup
# 5            Delivered            POSAgent                  Pickup
# 6            Delivered        PickUpPortal                  Pickup
# 7   Canceled#Delivered   POSAgent#POSAgent  PersonalReceipt#Pickup
# 8            Delivered        PickUpPortal                  Pickup
# 9            Delivered  PickUpTelesalesOwn                  Pickup
# 10           Delivered  PickUpTelesalesOwn                  Pickup
# 11           Delivered            POSAgent                  Pickup
# 12           Delivered  PickUpTelesalesOwn                  Pickup
# 13           Delivered  PickUpTelesalesOwn                  Pickup
# 14           Delivered  PickUpTelesalesOwn                  Pickup
# 15           Delivered            POSAgent                  Pickup
# 16           Delivered            POSAgent                  Pickup
# 17           Delivered        PickUpPortal                  Pickup
# 18           Delivered        PickUpPortal                  Pickup
# 19           Delivered  PickUpTelesalesOwn                  Pickup
#
#    SALESCHANNEL QTYRETURNED    DATA_GET_API_1              P_PICKUPSTATE  \
# 0            13           0  2024-06-20 00:09  PICKUP_READY_FOR_CUSTOMER
# 1            13           0  2024-06-20 00:07  PICKUP_READY_FOR_CUSTOMER
# 2            13           0  2024-06-20 00:07  PICKUP_READY_FOR_CUSTOMER
# 3            13           0  2024-06-20 00:07  PICKUP_READY_FOR_CUSTOMER
# 4             5           0  2024-06-20 00:05  PICKUP_READY_FOR_CUSTOMER
# 5            13           0  2024-06-20 00:05  PICKUP_READY_FOR_CUSTOMER
# 17   2024-06-24 23:00:00  Telepunkt#TP251#Marzena.Wielgos@orange.com#990...
# 18   2024-06-24 23:00:00  Telepunkt#TP081#Katarzyna.Smirnow@orange.com#2...
# 19   2024-06-25 23:00:00  POS#TL856#nowysacz.wegierska@tell.pl#1627Nowy ...
#
#                ORDER_ACTIVITIPROCESSSTEP P_STATUS_ORDER_OPIS  Unnamed: 15
# 0       CompleteProcessingStatusesAction             UNKNOWN          NaN
# 1            SendProxyNotificationAction          INPROGRESS          NaN
# 2       CompleteProcessingStatusesAction             UNKNOWN          NaN
# 3       CompleteProcessingStatusesAction             UNKNOWN          NaN
# 4            SendProxyNotificationAction          INPROGRESS          NaN
# 5       CompleteProcessingStatusesAction             UNKNOWN          NaN
# 6            SendProxyNotificationAction          INPROGRESS          NaN
# 7       CompleteProcessingStatusesAction             UNKNOWN          NaN
# 8   SendPickupReminderNotificationAction          INPROGRESS          NaN
# 9   SendPickupReminderNotificationAction          INPROGRESS          NaN
# 10  SendPickupReminderNotificationAction          INPROGRESS          NaN
# 11  SendPickupReminderNotificationAction          INPROGRESS          NaN
# 12  SendPickupReminderNotificationAction          INPROGRESS          NaN
# 13  SendPickupReminderNotificationAction          INPROGRESS          NaN
# 14  SendPickupReminderNotificationAction          INPROGRESS          NaN
# 15  SendPickupReminderNotificationAction          INPROGRESS          NaN
# 16  SendPickupReminderNotificationAction          INPROGRESS          NaN
# 17  SendPickupReminderNotificationAction          INPROGRESS          NaN
# 18  SendPickupReminderNotificationAction          INPROGRESS          NaN
# 19  SendPickupReminderNotificationAction          INPROGRESS          NaN

# %%
data_frame['SALESCHANNEL']
# Out:
# 0       13
# 1       13
# 2       13
# 3       13
# 4        5
# 5       13
# 6        5
# 7     5#13
# 8        5
# 9        5
# 10       5
# 11      13
# 12       5
# 13       5
# 14       5
# 15      13
# 16      13
# 17       5
# 18       5
# 19       5
# Name: SALESCHANNEL, dtype: object

# %%
data_frame['SALESCHANNEL'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data_frame['SALESCHANNEL'].plot()
#
# File ~/PycharmProjects/2024_06_Python/venv/lib/python3.11/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/PycharmProjects/2024_06_Python/venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/PycharmProjects/2024_06_Python/venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:499, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
# --> 499     self._compute_plot_data()
#     500     fig = self.fig
#     501     self._make_plot(fig)
#
# File ~/PycharmProjects/2024_06_Python/venv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:698, in MPLPlot._compute_plot_data(self)
#     696 # no non-numeric frames or series allowed
#     697 if is_empty:
# --> 698     raise TypeError("no numeric data to plot")
#     700 self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot
